# %%
import pandas as pd

# %% [markdown]
# ***
# ## Problem:
# You have a DataFrame df with columns 'A', 'B', and 'C', and you want to sort the DataFrame based on the values in column 'B' in ascending order. Write the code snippet?
#
#
# ## Code:

# %%
data = {
    "A": ["IT", "HR", "IT", "Finance", "HR", "Finance"],
    "B": ["Ellie", "Bravo", "Frank", "Candy", "Aditya", "Donnie"],
    "C": [70000, 50000, 80000, 60000, 52000, 65000]
}

df = pd.DataFrame(data)
print(df)
print("--------------------")

df_sorted_1 = df.sort_values("B") # Sorting the data frame column #1
print(df_sorted_1)
print("--------------------")

df_sorted_2 = df.sort_values(by="B") # Sorting the data frame column #2
print(df_sorted_2)
print("--------------------")

df_sorted_3 = df.sort_values(by="B", ascending=True) # Sorting the data frame column #3
print(df_sorted_3)
print("--------------------")

print(df)
print("--------------------")
df.sort_values(by="B", inplace=True) # Inplace sorting in the same data frame: return None
print(df)
print("--------------------")

# %% [markdown]
# ***
# ## Problem:
# You have a DataFrame df with columns 'A', 'B', and 'C', and you want to replace all occurrences of the value 0 in column 'A' with the mean of non-zero values in that column. Write the code snippet?
#
# ## Code:

# %%
df = pd.DataFrame({
    'A': [10, 0, 20, 0, 30],
    'B': [1, 2, 3, 4, 5],
    'C': ['X', 'Y', 'Z', 'P', 'Q']
})

print(df)
print("--------------------")

result_df = df['A'].replace(0, df['A'][df['A'] != 0].mean()) # Replaces all zero values in column 'A' with the mean of the non-zero values from that same column.
print(result_df)
print("--------------------")

# %% [markdown]
# ***
# ## Problem:
# How can you merge two DataFrames on a common column?
#
# ## Code:

# %%
df1 = pd.DataFrame({
    'common_column': [1, 2, 3],
    'A': ['a1', 'a2', 'a3']
})

df2 = pd.DataFrame({
    'common_column': [1, 2, 4],
    'B': ['b1', 'b2', 'b4']
})

merged_df_1 = pd.merge(df1, df2, on='common_column') # Merging dataframe df2 to df1
print(merged_df_1)
print("--------------------")

df3 = pd.DataFrame({
    'common_column': [1, 2, 4],
    'B': ['B1', 'B2', 'B4']
})

merged_df_2 = df1.merge(df3, on='common_column') # Merging dataframe df3 to df1
print(merged_df_2)

# %% [markdown]
# ***
# ## Problem:
# What will be the output of the following code snippet?
#
# ```
# import pandas as pd
# import numpy as np
# df = pd.DataFrame(np.random.randn(6, 4), columns=list('ABCD'))
# df[df.C > 0]
# ```
#
# ## Code:

# %%
import numpy as np

df = pd.DataFrame(np.random.randn(6, 4), columns=list('ABCD')) # Creates 6X4 dataframe with random values from a standard normal distribution
print(df)
print("--------------------")

print(df[df.C > 0]) # Data frame with column C's value greater than 0

# %% [markdown]
# ***
# ## Problem:
# What will be the output of the following code snippet?
#
# ```
# import pandas as pd
# data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
# df = pd.DataFrame(data)
# df.T
# ```
#
# ## Code:

# %%
data = {'A': [1, 2, 3], 'B': [4, 5, 6]}

df = pd.DataFrame(data)
print(df)
print("--------------------")

df.T # transposes the DataFrame using .T which swaps the rows and columns
print(df.T)

# %% [markdown]
# ***
# ## Problem:
# Which function should be used to drop a row by index from a DataFrame?
#
# ## Code:

# %%
df = pd.DataFrame({
    'A': [10, 20, 30, 40, 50, 60, 70],
    'B': [100, 200, 300, 400, 500, 600, 700],
    'C': [1000, 2000, 3000, 4000, 5000, 6000, 7000]
    })

dropped_df = df.drop(0) # dropping single row

print(dropped_df)
print("--------------------")

dropped_df = df.drop(index = 1) # dropping single row by explicitly calling index
print(dropped_df)
print("--------------------")

multi_row_dropped_df = df.drop([0, 2]) # dropping multiple rows
print(multi_row_dropped_df)
print("--------------------")

df.drop([0, 2, 5], inplace=True) # dropping multiple rows in the same data frame
print(df)

# %% [markdown]
# ***
# ## Problem:
# Which of the following code snippets can be used to reset the index of a DataFrame?
#
# ## Code:

# %%
df = pd.DataFrame({
    'A': [10, 20, 30]
}, index = [5, 6, 7])
print(df)
print("--------------------")

resetted_df = df.reset_index() # resets the index of the data frame
print(resetted_df)
print("--------------------")

resetted_df_dropped_row = df.reset_index(drop=True) # resets the index of the data frame and drops the old index
print(resetted_df_dropped_row)
print("--------------------")

df.reset_index(drop=True, inplace=True) # resets the index of the data frame in the same data frame and drops the old index
print(df)
print("--------------------")

df.reset_index(inplace=True) # resets the index of the data frame in the same data frame
print(df)
print("--------------------")

# %% [markdown]
# ***
# ## Problem:
# What will be the output of the following code snippet?
#
# ```
# import pandas as pd
# data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
# df = pd.DataFrame(data)
# df.at[1, 'B']
# ```
#
# ## Code:

# %%
data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
df = pd.DataFrame(data)
print(df)
print("--------------------")

print(df.at[1, 'B']) # The .at accessor is used to get a single value from the DataFrame based on its row and column labels.

# %% [markdown]
# ***
# ## Problem:
# Which method is used to group a DataFrame based on the values of one or more columns?
#
# ## Code:

# %%
df = pd.DataFrame({
    'Department': ['IT', 'HR', 'IT', 'Finance', 'HR'],
    'Salary': [70000, 50000, 80000, 60000, 52000]
})

grouped_df_1 = df.groupby('Department').mean() # Groups the DataFrame based on the values in the 'Department' column and get mean
print(grouped_df_1)

grouped_df_2 = df.groupby('Department').sum() # Groups the DataFrame based on the values in the 'Department' column and get sum
print(grouped_df_2)

grouped_df_3 = df.groupby('Department')['Salary'].mean() # Groups the DataFrame based on the values in the 'Department' column and get mean of the 'Salary' column
print(grouped_df_3)

# %% [markdown]
# ***
# ## Problem:
# What will be the output of the following code snippet?
#
# ```
# import pandas as pd
# data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
# df = pd.DataFrame(data)
# df.apply(lambda x: x**2)
# ```
#
# ## Code:

# %%
data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
df = pd.DataFrame(data)

print(df)
print("--------------------")

df = df.apply(lambda x: x**2) # The .apply() method is used to apply a function along an axis of the DataFrame. (by default, axis=0, which applies the function column-wise)
print(df)

# %% [markdown]
# ***
# ## Problem:
# Write a Python program using Pandas to create a DataFrame from the given data and calculate the average rating of movies directed by Christopher Nolan.
#
# ```
# data = {
#     'Title': ['Inception', 'Dunkirk', 'Interstellar', 'The Prestige', 'Memento'],
#     'Director': ['Christopher Nolan', 'Christopher Nolan', 'Christopher Nolan', 'Christopher Nolan', 'Christopher Nolan'],
#     'Rating': [8.8, 7.9, 8.6, 8.5, 8.4]
#
# }
# ```
# ## Code:

# %%
data = {
    'Title': ['Inception', 'Dunkirk', 'Interstellar', 'The Prestige', 'Memento'],
    'Director': ['Christopher Nolan', 'Christopher Nolan', 'Christopher Nolan', 'Christopher Nolan', 'Christopher Nolan'],
    'Rating': [8.8, 7.9, 8.6, 8.5, 8.4]

}

df = pd.DataFrame(data)

print(f"Total rating of all the {len(df['Title'])} is {df['Rating'].sum()}") # Pandas Series's sum funtion

print(f"Average rating of the {len(df['Title'])} movies is {df['Rating'].mean()}.") # Pandas Series's mean funtion

print("--------------------")

# %% [markdown]
# ***
# ## Problem:
# Given the following DataFrame, write a Python program using Pandas to extract all rows where the price is greater than or equal to 20,000 and sort them in descending order by price.
#
# ```
# data = {
#     'Product': ['Laptop', 'Desktop', 'Tablet', 'Phone', 'Smartwatch'],
#     'Price': [25000, 12000, 8000, 22000, 5000]
# }
# ```
# ## Code:

# %%
data = {
    'Product': ['Laptop', 'Desktop', 'Tablet', 'Phone', 'Smartwatch'],
    'Price': [25000, 12000, 8000, 22000, 5000]
}

df = pd.DataFrame(data)
print(df)
print("--------------------")

filtered_df = df[df['Price'] >= 20000].sort_values(by='Price', ascending = False) #Creating and sorting a filtered data frame by passing a condition
print(filtered_df)
print("--------------------")

# %% [markdown]
# ***
# ## **Problem:**
# Write a Python program using Pandas to create a DataFrame from the given data and find the total revenue and average price of items sold in each store.
#
# ```
# data = {
#     'Store': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
#     'Item': ['Apple', 'Banana', 'Orange', 'Grape', 'Apple', 'Banana', 'Orange', 'Grape'],
#     'Price': [50, 20, 30, 60, 55, 22, 33, 65],
#     'Quantity': [10, 12, 15, 16, 20, 25, 30, 35]
# }
# ```
#
# ## **Code:**

# %%
data = {
    'Store': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Item': ['Apple', 'Banana', 'Orange', 'Grape', 'Apple', 'Banana', 'Orange', 'Grape'],
    'Price': [50, 20, 30, 60, 55, 22, 33, 65],
    'Quantity': [10, 12, 15, 16, 20, 25, 30, 35]
}

df = pd.DataFrame(data)

# Create Total Revenue column
df['Total Revenue'] = df['Price'] * df['Quantity']
print(df)
print("--------------------")
df_s = df.groupby('Store')
print(df_s)
print("--------------------")

df_grouped = df.groupby('Store').agg(
    Total_Revenue=('Total Revenue', 'sum'),
    Average_Price=('Price', 'mean')
)

print(df_grouped)
print("--------------------")

# %% [markdown]
# ***
# ## **Problem:**
# Write a Python program using Pandas to create a DataFrame from the given data and calculate the total amount spent by each customer.
#
# ```
# data = {
#     'Customer': ['Alice', 'Bob', 'Alice', 'Alice', 'Bob', 'Bob', 'Alice', 'Bob'],
#     'Item': ['Pen', 'Pencil', 'Notebook', 'Eraser', 'Pen', 'Pencil', 'Notebook', 'Eraser'],
#     'Price': [10, 5, 50, 20, 10, 5, 50, 20],
#     'Quantity': [3, 4, 2, 5, 10, 6, 1, 2]
# }
# ```
#
# ## **Code:**

# %%
data = {
    'Customer': ['Alice', 'Bob', 'Alice', 'Alice', 'Bob', 'Bob', 'Alice', 'Bob'],
    'Item': ['Pen', 'Pencil', 'Notebook', 'Eraser', 'Pen', 'Pencil', 'Notebook', 'Eraser'],
    'Price': [10, 5, 50, 20, 10, 5, 50, 20],
    'Quantity': [3, 4, 2, 5, 10, 6, 1, 2]
}

df = pd.DataFrame(data)

df['Total Amount'] = df['Price'] * df['Quantity'] # Create new column wiht the total amount spent in that row.

print(df)
print("--------------------")

df_grouped = df.groupby('Customer').agg(
    Total_Amount=('Total Amount', 'sum')
) # Group the data frame by 'Customer' and aggregate the sum of the total amount for the groups.
print(df_grouped)

# %% [markdown]
# ***
# ## **Problem:**
# Write a Python program using Pandas to create a DataFrame from the given data and find the month with the highest average temperature.
# ```
# data = {
#     'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#     'Temperature': [20, 22, 25, 27, 30, 32, 35, 34, 30, 28, 24, 21]
# }
# ```
#
# ## **Code:**

# %%
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
    'Temperature': [20, 22, 25, 27, 30, 32, 35, 34, 30, 28, 24, 21]
}

df = pd.DataFrame(data)

print(df)

print("--------------------")

max_temp_row= df.loc[df['Temperature'].idxmax()] # Gives the row with max temperature

print(max_temp_row)
print("--------------------")

max_month = df.loc[df['Temperature'].idxmax(), 'Month'] # Find the index of the maximum value in the 'Temperature' column
print(max_month)

# %% [markdown]
# ## **Description:**
# * **.loc** in Pandas is used to select rows and columns by their labels (names).
# * Here, `df.loc[df['Temperature'].idxmax(), 'Month']` picks the row for the max 'Temperature' and returns corresponding value in the column 'Month'.

# %% [markdown]
# ***
# ## **Problem:**
# Given the following DataFrame and code snippet, predict the output of the code.
# ```
# data = {
#     'Category': ['Fruit', 'Vegetable', 'Fruit', 'Vegetable', 'Fruit', 'Vegetable'],
#     'Name': ['Apple', 'Carrot', 'Banana', 'Potato', 'Grape', 'Onion'],
#     'Price': [2, 1, 1.5, 0.5, 3, 1],
#     'Quantity': [10, 20, 15, 30, 5, 40]
# }
#
# df = pd.DataFrame(data)
#
# fruits = df[df['Category'] == 'Fruit']
# total_fruit_value = fruits['Price'].sum() * fruits['Quantity'].sum()
#
# print(total_fruit_value)
# ```
#
# ## **Code:**

# %%
data = {
    'Category': ['Fruit', 'Vegetable', 'Fruit', 'Vegetable', 'Fruit', 'Vegetable'],
    'Name': ['Apple', 'Carrot', 'Banana', 'Potato', 'Grape', 'Onion'],
    'Price': [2, 1, 1.5, 0.5, 3, 1],
    'Quantity': [10, 20, 15, 30, 5, 40]
}

df = pd.DataFrame(data)

fruits = df[df['Category'] == 'Fruit'] # Filtering dataframe for Fruit in Category column

total_fruit_value = fruits['Price'].sum() * fruits['Quantity'].sum() # In the filtered dataframe with fruits, calculating product of the total price and total quantity.

print(total_fruit_value)

# Answer: 195.0

# %% [markdown]
# ***
# ## **Problem:**
# Given the following DataFrame and code snippet, predict the output of the code.
# ```
# data = {
#     'Name': ['Alice', 'Bob', 'Charlie', 'David'],
#     'Age': [25, 30, 35, 40],
#     'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago']
# }
#
# df = pd.DataFrame(data)
#
# result = df[df['Age'] >= 30].sort_values(by='Age', ascending=False).iloc[0]['City']
#
# print(result)
# ```
#
# ## **Code:**

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)

result = df[df['Age'] >= 30].sort_values(by='Age', ascending=False).iloc[0]['City']
# Filters data frame to data points with age more than or equal to 30.
# Sorts the filtered data frame in reverse order.
# Gives the value in 'City' column for the 0th row index.

print(result)

# Answer: Chicago

# %% [markdown]
# ## **Explanation:**
# * In pandas, **iloc[row][col]** is used for integer-location based indexing.
# * It lets you **select rows and columns by their numeric position** (index number) rather than by label.

# %% [markdown]
# ***
# ## **Problem:**
# Given the following DataFrame and code snippet, predict the output of the code.
#
# ```
# data = {
#     'Product': ['A', 'B', 'C', 'A', 'B', 'C'],
#     'Price': [100, 200, 300, 150, 250, 350],
#     'Quantity': [10, 5, 7, 12, 8, 5]
# }
#
# df = pd.DataFrame(data)
#
# total_revenue = (df['Price'] * df['Quantity']).sum()
# average_price = df['Price'].mean()
#
# print(total_revenue, average_price)
# ```
#
# ## **Code:**

# %%
data = {
    'Product': ['A', 'B', 'C', 'A', 'B', 'C'],
    'Price': [100, 200, 300, 150, 250, 350],
    'Quantity': [10, 5, 7, 12, 8, 5]
}

df = pd.DataFrame(data)

total_revenue = (df['Price'] * df['Quantity']).sum()

print((df['Price'] * df['Quantity']).sum()) # Creates a new series with the product of Price and Quantity in each row and then caluclates sum of the series.

average_price = df['Price'].mean() # Calculates mean of the Price column.

print(total_revenue, average_price)

# Answer: 9650 225.0

# %% [markdown]
# ***
# ## **Problem:**
# Write a Python program using Pandas to create a DataFrame from the given data and find the total amount spent per item, as well as the total amount spent by all customers.
# ```
# data = {
#     'Customer': ['Alice', 'Bob', 'Alice', 'Alice', 'Bob', 'Bob', 'Alice', 'Bob'],
#     'Item': ['Pen', 'Pencil', 'Notebook', 'Eraser', 'Pen', 'Pencil', 'Notebook', 'Eraser'],
#     'Price': [10, 5, 50, 20, 10, 5, 50, 20],
#     'Quantity': [3, 4, 2, 5, 10, 6, 1, 2]
# }
# ```
#
# ## **Code:**

# %%
data = {
    'Customer': ['Alice', 'Bob', 'Alice', 'Alice', 'Bob', 'Bob', 'Alice', 'Bob'],
    'Item': ['Pen', 'Pencil', 'Notebook', 'Eraser', 'Pen', 'Pencil', 'Notebook', 'Eraser'],
    'Price': [10, 5, 50, 20, 10, 5, 50, 20],
    'Quantity': [3, 4, 2, 5, 10, 6, 1, 2]
}

df = pd.DataFrame(data)

df['Total_price'] = df['Price'] * df['Quantity']

print(df)

spent_per_item_df = df.groupby('Item').agg(Total_price = ('Total_price', 'sum'))
print(spent_per_item_df)
print("--------------------")

spending_per_customer_df = df.groupby('Customer').agg(Total_spending = ('Total_price', 'sum'))
print(spending_per_customer_df)
print("--------------------")

# %% [markdown]
# ***
# ## **Problem:**
# Write a Python program using Pandas to create a DataFrame from the given data and calculate the monthly average temperature difference between two cities.
# ```
# data = {
#     'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#     'City_A_Temp': [20, 22, 25, 27, 30, 32, 35, 34, 30, 28, 24, 21],
#     'City_B_Temp': [10, 12, 15, 17, 20, 22, 25, 24, 20, 18, 14, 11]
# }
# ```
#
# ## **Code:**

# %%
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
    'City_A_Temp': [20, 22, 25, 27, 30, 32, 35, 34, 30, 28, 24, 21],
    'City_B_Temp': [10, 12, 15, 17, 20, 22, 25, 24, 20, 18, 14, 11]
}
df = pd.DataFrame(data)

df['Temp_diff'] = df['City_A_Temp'] - df['City_B_Temp']

print(df['Temp_diff'].mean())

print("----------------------")

# Pythonic way:

avg_diff = (df['City_A_Temp'] - df['City_B_Temp']).mean()
print(avg_diff)
# Out:
# 10.0
# ----------------------
# 10.0
